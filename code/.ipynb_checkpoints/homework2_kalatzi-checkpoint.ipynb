# %%
########################################################
# Purpose: Data Engineering exercise
# Author: Marilena Kalatzi
# Date: May 2024
########################################################

# %%
# import pandas library
import pandas as pd

# %% [markdown]
# **Load Data**
#
# In the next 7 chunks of code, we provide the steps required to obtain a final data frame of the data. After mapping the variables in the right data types and selecting some appropriate columns for the exercise, we will load a sample of each file in the memory, process it accordingly and then save it in a collective data frame. When the process is completed for all the 12 files available, we will be left with a data frame that will contain all the previously merged data frames. In order for the code of the next 7 chunks to run, you will need to first save all the required csv files in your computer using this link: https://data.sba.gov/dataset/ppp-foia

# %%
# map variable types 
dtype_mapping = {
    'LoanNumber': 'str', 'DateApproved': 'str', 'BorrowerCity': 'str', 'BorrowerState': 'category',
    'BorrowerZip': 'str', 'LoanStatusDate': 'str', 'LoanStatus': 'category', 'Term': 'Int32',
    'SBAGuarantyPercentage': 'float32', 'InitialApprovalAmount': 'float32', 'CurrentApprovalAmount': 'float32',
    'UndisbursedAmount': 'float32', 'ServicingLenderName': 'str', 'ServicingLenderCity': 'str',
    'ServicingLenderState': 'category', 'JobsReported': 'float32', 'BusinessType': 'category', 'Race': 'category',
    'Ethnicity': 'category', 'Gender': 'category', 'Veteran': 'category', 'NonProfit': 'category',
    'ForgivenessAmount': 'float32', 'ForgivenessDate': 'str'
}

# %%
# select appropriate columns for analysis
selected_columns = ['LoanNumber', 'DateApproved', 'BorrowerName', 'BorrowerCity', 'BorrowerState', 'BorrowerZip',
    'LoanStatusDate', 'LoanStatus', 'Term', 'SBAGuarantyPercentage', 'InitialApprovalAmount',
    'CurrentApprovalAmount', 'UndisbursedAmount', 'ServicingLenderName', 'ServicingLenderCity',
    'ServicingLenderState', 'JobsReported', 'BusinessType', 'Race', 'Ethnicity', 'Gender', 'Veteran',
    'NonProfit', 'ForgivenessAmount', 'ForgivenessDate']

# %%
import os

# Define the folder path
folder_path = 'C:/Users/Yasir/OneDrive - aueb.gr/Desktop/MSc. Statistics/Data Engineering/homework_2/CovidRecovery/RawData'
output_folder = 'C:/Users/Yasir/OneDrive - aueb.gr/Desktop/MSc. Statistics/Data Engineering/homework_2/CovidRecovery/RawData'


def process_file(file_path, output_path):
    
    # Load the data with specified data types and only selected columns
    df = pd.read_csv(file_path, usecols=selected_columns, dtype=dtype_mapping)
    
    # Take a random sample of 10% of the data
    df_sample = df.sample(frac=0.1, random_state=1)
    
    # Save the sampled data of each file to a new CSV file
    df_sample.to_csv(output_path, index=False)
    return df_sample

# %%
# create an empty list to fill with each file
results = []

# list of files to work with
csv_files = [f"public_up_to_150k_{i}_230930.csv" for i in range(1, 13)]
csv_files = [os.path.join(folder_path, f) for f in csv_files]

# %%
# process each file
for file_path in csv_files:
    output_path = os.path.join(output_folder, f'sampled_{os.path.basename(file_path)}')
    df_sample = process_file(file_path, output_path)
    results.append(df_sample)

# Concatenate all DataFrames in the results list into a single DataFrame
all_sampled_data_df = pd.concat(results, ignore_index=True)

# Display the whole DataFrame info and memory usage
print(all_sampled_data_df.info(memory_usage='deep'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1049977 entries, 0 to 1049976
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   LoanNumber             1049977 non-null  object
#  1   DateApproved           1049977 non-null  object
#  2   BorrowerName           1049972 non-null  object
#  3   BorrowerCity           1049963 non-null  object
#  4   BorrowerState          1049962 non-null  object
#  5   BorrowerZip            1049962 non-null  object
#  6   LoanStatusDate         1021461 non-null  object
#  7   LoanStatus             1049977 non-null  category
#  8   Term                   1049977 non-null  Int32
#  9   SBAGuarantyPercentage  1049977 non-null  float32
#  10  InitialApprovalAmount  1049977 non-null  float32
#  11  CurrentApprovalAmount  1049977 non-null  float32
#  12  UndisbursedAmount      1049876 non-null  float32
#  13  ServicingLenderName    1049973 non-null  object
#  14  ServicingLenderCity    1049973 non-null  object
#  15  ServicingLenderState   1049973 non-null  object
#  16  JobsReported           1049977 non-null  float32
#  17  Race                   1049977 non-null  object
#  18  Ethnicity              1049977 non-null  category
#  19  BusinessType           1049818 non-null  object
#  20  Gender                 1049977 non-null  category
#  21  Veteran                1049977 non-null  category
#  22  NonProfit              21337 non-null    category
#  23  ForgivenessAmount      962080 non-null   float32
#  24  ForgivenessDate        962080 non-null   object
# dtypes: Int32(1), category(5), float32(6), object(13)
# memory usage: 917.9 MB
# None

# %%
# Save the final concatenated DataFrame to a CSV file
all_sampled_data_df.to_csv(os.path.join(output_folder, 'all_sampled_data.csv'), index=False)

# Display the head of the concatenated DataFrame
print(all_sampled_data_df.head())

# %%
# Rename the DataFrame all_sampled_data_df by assigning it to a new variable
data = all_sampled_data_df

# Delete the original DataFrame variable
del all_sampled_data_df

# %% [markdown]
# **DATA CLEANING**

# %%
# print the first 5 rows of data
print(data.head())
# Out:
#    LoanNumber DateApproved              BorrowerName      BorrowerCity  \
# 0  7294738309   01/28/2021  IDEAL MANUFACTURING INC.           Hayward
# 1  1501648803   04/10/2021      WIRELESS EXPRESS LLC           Phoenix
# 2  8375968500   03/09/2021              JOHN SCIALLI           Phoenix
# 3  1797258410   02/02/2021            RICHARD TAYLOR  Huntington Beach
# 4  6308417210   04/27/2020           VISIONECT, INC.     Mountain View
#
#   BorrowerState BorrowerZip LoanStatusDate    LoanStatus  Term  \
# 0            CA  94544-6900     02/19/2022  Paid in Full    60
# 1            AZ  85051-5801     10/19/2021  Paid in Full    60
# 2            AZ  85018-3344     09/25/2021  Paid in Full    60
# 3            CA  92646-2406     02/18/2021  Paid in Full    60
# 4            CA       94041     03/23/2021  Paid in Full    24
#
#    SBAGuarantyPercentage  ...  ServicingLenderState  JobsReported        Race  \
# 0                  100.0  ...                    NY          10.0       Asian
# 1                  100.0  ...                    UT          15.0  Unanswered
# 2                  100.0  ...                    OK           2.0       White
# 3                  100.0  ...                    SD           4.0       White
# 4                  100.0  ...                    NC           2.0  Unanswered
#
#                 Ethnicity                     BusinessType        Gender  \
# 0  Not Hispanic or Latino                      Corporation  Female Owned
# 1       Unknown/NotStated  Limited  Liability Company(LLC)    Unanswered
# 2  Not Hispanic or Latino              Sole Proprietorship    Male Owned
# 3       Unknown/NotStated              Sole Proprietorship    Male Owned
# 4       Unknown/NotStated                      Corporation    Male Owned
#
#        Veteran NonProfit ForgivenessAmount ForgivenessDate
# 0  Non-Veteran       NaN          93443.24      10/20/2021
# 1   Unanswered       NaN          45295.68      09/20/2021
# 2  Non-Veteran       NaN          17174.37      08/11/2021
# 3  Non-Veteran       NaN          30384.17      05/17/2022
# 4   Unanswered       NaN          33325.40      02/19/2021
#
# [5 rows x 25 columns]

# %%
# examine if all the values of non profit are: NaN
data['NonProfit'].isna().all()
# Out:
# False

# %%
# count how many NaN values are in NonProfit variable
non_counts_non_profit = data['NonProfit'].isna().sum()
obs_non_profit = len(data['NonProfit'])
print(f"Number of NaN values in 'NonProfit': {non_counts_non_profit}, Total number of observations in 'NonProfit': {obs_non_profit}")

# Calculate the frequency of NaN values
nan_frequency = non_counts_non_profit / obs_non_profit

# Print the results
print(f"Number of NaN values in 'NonProfit': {non_counts_non_profit}")
print(f"Total number of observations in 'NonProfit': {obs_non_profit}")
print(f"Frequency of NaN values in 'NonProfit': {nan_frequency:.2f}")
# Out:
# Number of NaN values in 'NonProfit': 1028640, Total number of observations in 'NonProfit': 1049977
# Number of NaN values in 'NonProfit': 1028640
# Total number of observations in 'NonProfit': 1049977
# Frequency of NaN values in 'NonProfit': 0.98

# %%
# examine if SBAGuarantyPercentage has only values = 100
(data['SBAGuarantyPercentage'] == 100).all()
# Out:
# True

# %%
# drop column NonProfit since 98% of its observations are missing, and SBAGuarantyPercentage since all its variables are 100
data = data.drop(columns=['NonProfit', 'SBAGuarantyPercentage'])

# %%
# print the dataframe again
print(data.head())
# Out:
#    LoanNumber DateApproved              BorrowerName      BorrowerCity  \
# 0  7294738309   01/28/2021  IDEAL MANUFACTURING INC.           Hayward
# 1  1501648803   04/10/2021      WIRELESS EXPRESS LLC           Phoenix
# 2  8375968500   03/09/2021              JOHN SCIALLI           Phoenix
# 3  1797258410   02/02/2021            RICHARD TAYLOR  Huntington Beach
# 4  6308417210   04/27/2020           VISIONECT, INC.     Mountain View
#
#   BorrowerState BorrowerZip LoanStatusDate    LoanStatus  Term  \
# 0            CA  94544-6900     02/19/2022  Paid in Full    60
# 1            AZ  85051-5801     10/19/2021  Paid in Full    60
# 2            AZ  85018-3344     09/25/2021  Paid in Full    60
# 3            CA  92646-2406     02/18/2021  Paid in Full    60
# 4            CA       94041     03/23/2021  Paid in Full    24
#
#    InitialApprovalAmount  ...  ServicingLenderCity  ServicingLenderState  \
# 0                92800.0  ...             NEW YORK                    NY
# 1                45099.0  ...       SALT LAKE CITY                    UT
# 2                17105.0  ...        OKLAHOMA CITY                    OK
# 3                30000.0  ...          Sioux Falls                    SD
# 4                33060.7  ...              Raleigh                    NC
#
#   JobsReported        Race               Ethnicity  \
# 0         10.0       Asian  Not Hispanic or Latino
# 1         15.0  Unanswered       Unknown/NotStated
# 2          2.0       White  Not Hispanic or Latino
# 3          4.0       White       Unknown/NotStated
# 4          2.0  Unanswered       Unknown/NotStated
#
#                       BusinessType        Gender      Veteran  \
# 0                      Corporation  Female Owned  Non-Veteran
# 1  Limited  Liability Company(LLC)    Unanswered   Unanswered
# 2              Sole Proprietorship    Male Owned  Non-Veteran
# 3              Sole Proprietorship    Male Owned  Non-Veteran
# 4                      Corporation    Male Owned   Unanswered
#
#   ForgivenessAmount ForgivenessDate
# 0          93443.24      10/20/2021
# 1          45295.68      09/20/2021
# 2          17174.37      08/11/2021
# 3          30384.17      05/17/2022
# 4          33325.40      02/19/2021
#
# [5 rows x 23 columns]

# %% [markdown]
# **Analyze Data**

# %%
# load packages to make plots
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Set the aesthetic style of the plots
sns.set_style("whitegrid")

# Precompute the counts for Ethnicity
ethnicity_counts = data['Ethnicity'].value_counts()

# Plot for Ethnicity
# Adjusting the context to increase font sizes
sns.set_context("notebook", font_scale=1.5)

plt.figure(figsize=(10, 6))
sns.barplot(y=ethnicity_counts.index, x=ethnicity_counts.values, palette='Blues_d')
plt.title('Ethnicity Distribution', fontsize=20)
plt.xlabel('Count', fontsize=15)
plt.ylabel('Ethnicity', fontsize=15)

# Adjusting the tick label sizes
plt.tick_params(axis='both', which='major', labelsize=12)

plt.savefig('ethnicity_distribution.jpg', format='jpg')
plt.show()

# %%
# Precompute the counts for Race
race_counts = data['Race'].value_counts()

# Adjusting the context to increase font sizes
sns.set_context("notebook", font_scale=1.5)

plt.figure(figsize=(10, 6))
sns.barplot(y=race_counts.index, x=race_counts.values, palette='Greens_d')
plt.title('Race Distribution', fontsize=20)
plt.xlabel('Count', fontsize=15)
plt.ylabel('Race', fontsize=15)

# Adjusting the tick label sizes
plt.tick_params(axis='both', which='major', labelsize=12)

# Save the figure
plt.savefig('race_distribution.jpg', format='jpg')
plt.show()

# %%
# Precompute the counts for Gender
gender_counts = data['Gender'].value_counts()

# Adjusting the context to increase font sizes
sns.set_context("notebook", font_scale=1.5)

plt.figure(figsize=(10, 6))
sns.barplot(y=gender_counts.index, x=gender_counts.values, palette='Reds_d')
plt.title('Gender Distribution', fontsize=20)
plt.xlabel('Count', fontsize=15)
plt.ylabel('Gender', fontsize=15)

# Adjusting the tick label sizes
plt.tick_params(axis='both', which='major', labelsize=12)

# Save the figure
plt.savefig('gender_distribution.jpg', format='jpg')
plt.show()

# %%
# Precompute the counts for BorrowerState
state_counts = data['BorrowerState'].value_counts().reset_index()
state_counts.columns = ['BorrowerState', 'Count']

# Generate a color palette with the same number of colors as the number of states
palette = sns.color_palette("Blues_d", len(state_counts))

# Sort the palette based on the count
palette = palette[::-1]

# Adjusting the context to increase font sizes
sns.set_context("notebook", font_scale=1.5)

plt.figure(figsize=(10, 12))
sns.barplot(x='Count', y='BorrowerState', data=state_counts, palette=palette, orient='h')
plt.title('Borrower State Distribution', fontsize=20)
plt.xlabel('Count', fontsize=15)
plt.ylabel('State', fontsize=15)

# Adjusting the tick label sizes
plt.tick_params(axis='both', which='major', labelsize=12)

# Save the figure
plt.savefig('borrower_state_distribution.jpg', format='jpg')
plt.show()
